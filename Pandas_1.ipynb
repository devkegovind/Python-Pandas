# %% [markdown]
# <a href="https://colab.research.google.com/github/devkegovind/Python-Pandas/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align='center'><b>DATE MANIPULATION OPERTION ON TITANIC DATA SET</b></h1>

# %% [markdown]
# <h4><b>Import the Library & Dataset</b></h4>

# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>Fetch the First Five Records/Rows of DataFrame</b></h4>
#
#   -  Default value is 5.

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# <h4><b>Fetch the Last Five Records/Rows of DataFrame</b></h4>

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# <h4><b>To know the Datatype of each column/attributes in the DataFrame</b></h4>

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# <h4><b>To Fetch the Full Information of DataFrame</b></h4>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <h4><b>To Fetch statistical information of DataFrame on int/float datatype of attributes/columns</b></h4>

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <h4><b>To Fetch statistical information of DataFrame on object/string attributes/columns</b></h4>

# %%
data[['Name', 'Sex', 'Ticket']].describe()
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %%
data.select_dtypes('object').describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# <h4><b>Fetch the attributes/columns whose datatype = 'object' from DataFrame</b></h4>

# %%
data.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data.select_dtypes(include = ['object'])
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %% [markdown]
# <h4><b>Fetch the attributes/columns whose datatype = 'int' from DataFrame</b></h4>

# %%
data.dtypes == 'int'
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[data.dtypes == 'int']
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
data.dtypes[data.dtypes == 'int'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
data[data.dtypes[data.dtypes == 'int'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
data.select_dtypes(include=['int'])
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %% [markdown]
# <h4><b>Fetch the attributes/columns whose datatype = 'float' from DataFrame</b></h4>

# %%
data.dtypes == 'float'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[data.dtypes == 'float']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
data.dtypes[data.dtypes == 'float'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
data[data.dtypes[data.dtypes == 'float'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
data.select_dtypes(include=['float'])
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# <h4><b>Fetch the records/rows whose value is "Survived == 0" from DataFrame</b></h4>

# %%
data['Survived'] == 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %%
data[data["Survived"] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# <h4><b>Fetch the records/rows whose value are "Survived == 0 and Sex == male" from DataFrame</b></h4>

# %%
data[(data["Survived"] == 0) & (data["Sex"] == "male")].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %% [markdown]
# <h4><b>Fetch the count of whose values are "Survived == 0 and Sex == male" from DataFrame</b></h4>

# %%
len(data[(data['Survived'] == 0) & (data['Sex'] == 'male')])
# Out:
# 468

# %% [markdown]
# <h4><b>Fetch the count of whose values are "Survived == 0 and Sex == female" from DataFrame</b></h4>

# %%
len(data[(data['Survived']==0) & (data['Sex']=='female')])
# Out:
# 81

# %% [markdown]
# <h4><b>Fetch the count Sex wise from DataFrame</b></h4>

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(data[data['Sex'] == 'male'])
# Out:
# 577

# %%
len(data[data['Sex'] == 'female'])
# Out:
# 314

# %% [markdown]
# <h4><b>Fetch the count of whose values are "Survived == 1 and Sex == male" from DataFrame</b></h4>

# %%
len(data[(data['Survived'] == 1) & (data['Sex'] == 'male')])
# Out:
# 109

# %% [markdown]
# <h4><b>Fetch the count of whose values are "Survived == 1 and Sex == female" from DataFrame</b></h4>

# %%
len(data[(data['Survived']==1) & (data['Sex'] == 'female')])
# Out:
# 233

# %% [markdown]
# <h4><b>To Fetch the maximum fare value from DataFrame</b></h4>

# %%
max(data['Fare'])
# Out:
# 512.3292

# %% [markdown]
# <h4><b>To Fetch the minimum fare value from DataFrame</b></h4>

# %%
min(data['Fare'])
# Out:
# 0.0

# %% [markdown]
# <h4><b>To Fetch the Name of person who paid maximum fare from DataFrame</b></h4>

# %%
data[data['Fare'] == max(data['Fare'])][['Name']]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %% [markdown]
# <h4><b>To Fetch the records/rows who paid maximum fare from DataFrame</b></h4>

# %%
data[data['Fare'] == max(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %% [markdown]
# <h4><b>To Fetch the records/rows who paid minimum fare from DataFrame</b></h4>

# %%
data[data['Fare'] == min(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %% [markdown]
# <h4><b>To Fetch all the records/rows whose "Cabin is not equal to NaN" from DataFrame</b></h4>

# %%
data[data['Cabin'] != 'nan']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data['Cabin'].isnull() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>To Count the value whose "cabin is Not equal to Null" from DataFrame</b></h4>

# %%
len(data[data['Cabin'].isnull() == False])
# Out:
# 204

# %% [markdown]
# <h4><b>To Add a New Column into Existing DataFrame and whose values = "GVD"</b></h4>

# %%
data['New_Col'] = "GVD"

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>To make a copy of existing column from DataFrame and add a New Column</b></h4>

# %%
data['New_Col1'] = data['Name']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>To add new column into DataFrame which is form by adding two existing column from DataFrame</b></h4>

# %%
data["Age_Pclass"] = data["Age"] + data["Pclass"]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>To Delete the column permanently from DataFrame</b></h4>

# %%
data.drop("New_Col", axis = 1, inplace = True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>To Delete the row/record from DataFrame</b></h4>

# %%
data = data.drop(0)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>To Fetch the row/record of DataFrame with the help of .iloc and .loc</b></h4>

# %%
data.iloc[0]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# New_Col1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# Age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# New_Col1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# Age_Pclass                                                  39.0
# Name: 1, dtype: object

# %% [markdown]
# <h4><b>To Fetch the rows/records from 2 to 5 from DataFrame</b></h4>

# %%
data.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  \
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
#
#                                        New_Col1  Age_Pclass
# 2                        Heikkinen, Miss. Laina        29.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0
# ...

# %% [markdown]
# <h4><b>To fetch records/rows whose "Age > 35" from DataFrame</b></h4>

# %%
data[data["Age"] > 35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4><b>To Fetch the rows/records with specified columns from DataFrame</b></h4>

# %%
data.loc[[3,5], ['PassengerId', 'Survived', 'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
data.iloc[[2, 4], 0:3]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
data.iloc[:, 0:3]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [890 rows x 3 columns]

# %%
data.loc[:, ['PassengerId', 'Pclass']]
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
data.iloc[:,0:2]
# Out:
#      PassengerId  Survived
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# 5              6         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [890 rows x 2 columns]

# %%
data.loc[3:4, ['Fare', 'Cabin', 'Embarked']]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.iloc[[3, 4], [9, 10, 11]]
# Out:
#      Fare Cabin Embarked
# 4  8.0500   NaN        S
# 5  8.4583   NaN        Q

# %%
data.loc[101:106, ['Survived', 'Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
data1 = data.iloc[1:5, [2, 3, 4, 5, 9, 10]]

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %% [markdown]
# <h4><b>To Set the column as index From DataFrame</b></h4>

# %%
data1.set_index('Name', inplace = True)

# %%
data1
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %% [markdown]
# <h4><b>To Drop/remove Missing/NaN Values From DataFrame</b></h4>

# %%
data1.dropna()
# Out:
#                                               Pclass     Sex   Age  Fare Cabin
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1  C123

# %%
data1.dropna(axis=1)
# Out:
#                                               Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                             3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  53.1000
# Allen, Mr. William Henry                           3    male   8.0500
# Moran, Mr. James                                   3    male   8.4583

# %%
data1.dropna(axis=1, thresh = 1)
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
data1.dropna(axis = 1, thresh = 2 )
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583

# %%
data1.dropna(axis=0, thresh = 4)
# Out:
#                                               Pclass     Sex   Age    Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.925
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.100
# Allen, Mr. William Henry                           3    male  35.0   8.050
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN

# %%
data1.fillna("GVD")
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   GVD   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         GVD
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       GVD
# Moran, Mr. James                               GVD

# %%
data1.fillna(data1['Age'].mean())
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male  32.0   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                        32.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                      32.0
# Moran, Mr. James                              32.0

# %%
data1.groupby("Sex").sum()['Fare']
# Out:
# Sex
# female    61.0250
# male      16.5083
# Name: Fare, dtype: float64

# %%
data1.groupby("Sex").mean()['Age']
# Out:
# Sex
# female    30.5
# male      35.0
# Name: Age, dtype: float64

# %%
data2 = data.iloc[0:4, 0:5]

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %% [markdown]
# <h4><b>To conacat/combine two DataFrame</b></h4>

# %%
pd.concat([data1, data2])
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
# 1                                                  1  female   NaN      NaN
# 2                                                  3  female   NaN      NaN
# 3                                                  1  female   NaN      NaN
# 4                                                  3    male   NaN      NaN
#
#                                              Cabin  PassengerId  Survived  \
# Heikkinen, Miss. Laina                         NaN          NaN       NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123          NaN       NaN
# ...

# %% [markdown]
# <h4><b>To combine two DataFrame Column wise</b></h4>

# %%
pd.concat([data1, data2], axis = 1)
# Out:
#                                               Pclass     Sex   Age     Fare  \
# 1                                                NaN     NaN   NaN      NaN
# 2                                                NaN     NaN   NaN      NaN
# 3                                                NaN     NaN   NaN      NaN
# 4                                                NaN     NaN   NaN      NaN
# Allen, Mr. William Henry                         3.0    male  35.0   8.0500
# Futrelle, Mrs. Jacques Heath (Lily May Peel)     1.0  female  35.0  53.1000
# Heikkinen, Miss. Laina                           3.0  female  26.0   7.9250
# Moran, Mr. James                                 3.0    male   NaN   8.4583
#
#                                              Cabin  PassengerId  Survived  \
# 1                                              NaN          2.0       1.0
# 2                                              NaN          3.0       1.0
# ...

# %%
data1
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
data1['New'] = data1['Pclass'].apply(lambda x : x/3)

# %%
data1
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin       New
# Name
# Heikkinen, Miss. Laina                         NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123  0.333333
# Allen, Mr. William Henry                       NaN  1.000000
# Moran, Mr. James                               NaN  1.000000

# %% [markdown]
# <h4><b>To apply Function to specific column of DataFrame</b></h4>

# %%
def fun1(x):
  return x/3

# %%
data1['new1'] = data1['Pclass'].apply(fun1)

# %%
data1
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin       New      new1
# Name
# Heikkinen, Miss. Laina                         NaN  1.000000  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123  0.333333  0.333333
# Allen, Mr. William Henry                       NaN  1.000000  1.000000
# Moran, Mr. James                               NaN  1.000000  1.000000

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
import math 
def func2(x):
  if x < 3:
    return x
  else:
    return math.log10(x)

# %%
data2['Passenger_Id_New'] = data2['PassengerId'].apply(func2)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Passenger_Id_New
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female          2.000000
# 2                             Heikkinen, Miss. Laina  female          0.477121
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female          0.602060
# 4                           Allen, Mr. William Henry    male          0.698970

# %%
def test1(x):
  if x == 'female':
    return 1
  else:
    return 0

# %%
data2['Sex'] = data2['Sex'].apply(test1)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Passenger_Id_New
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1          2.000000
# 2                             Heikkinen, Miss. Laina    1          0.477121
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1          0.602060
# 4                           Allen, Mr. William Henry    0          0.698970

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def test2(x):
  if x <= 100:
    return "A"
  elif x > 101 and x < 200:
    return "B"
  else:
    return "C"

# %%
data['Fare_group'] = data['Fare'].apply(test2)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Name_Len'] = data['Name'].apply(len)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...
